# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

repo_path = '/content/optimized-summarization'
if not os.path.exists(repo_path):
    # !git clone https://github.com/srinisvas/optimized-summarization.git
else:
    print("Repo already exists, skipping clone.")

# Check files inside
os.listdir(repo_path)
# Out:
# Repo already exists, skipping clone.
# ['.git',
#  'README.md',
#  'optimized-summarization',
#  'TF-ID_similarity_matrix',
#  '.idea']

# %%
import os
  # Adjust your folder
INPUT_DIR = '/content/optimized-summarization/optimized-summarization/Normalized-papers/'
TF_IDF_OUTPUT_DIR = '/content/drive/MyDrive/TF-ID_similarity_matrix/'
TEXTRANK_OUTPUT_DIR = '/content/drive/MyDrive/Textrank_scores/'

os.makedirs(TF_IDF_OUTPUT_DIR, exist_ok=True)
os.makedirs(TEXTRANK_OUTPUT_DIR, exist_ok=True)

# %%
import json
import spacy

nlp = spacy.load("en_core_web_sm")

def extract_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        paper = json.load(f)
    sentences = []
    for sec in paper['sections']:
        doc = nlp(sec['content'])
        sentences.extend([sent for sent in doc.sents])
    return sentences

# %%
def clean_sentences(sentences):
    sentences_cleaned = []
    for sent in sentences:
        words = [word.text for word in sent if not word.is_punct]
        sentences_cleaned.append(" ".join(words))
    return sentences_cleaned

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def compute_tfidf_similarity(sentences_cleaned):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(sentences_cleaned)
    similarity_matrix = cosine_similarity(tfidf_matrix)
    return tfidf_matrix, similarity_matrix

# %%
import networkx as nx

def compute_textrank(similarity_matrix, damping=0.85, max_iter=100):
    nx_graph = nx.from_numpy_array(similarity_matrix)
    scores = nx.pagerank(nx_graph, alpha=damping, max_iter=max_iter)
    # Convert to list sorted by sentence index
    textrank_scores = [scores[i] for i in range(len(scores))]
    return textrank_scores

# %%
# Process all files
for file_name in os.listdir(INPUT_DIR):
    if file_name.endswith(".json"):
        file_path = os.path.join(INPUT_DIR, file_name)

        # Extract and clean sentences
        sentences = extract_sentences(file_path)
        sentences_cleaned = clean_sentences(sentences)

        # TF-IDF and similarity
        tfidf_matrix, similarity_matrix = compute_tfidf_similarity(sentences_cleaned)

        # Save TF-IDF similarity matrix
        tfidf_file = os.path.join(TF_IDF_OUTPUT_DIR, file_name.replace('.json', '_similarity.npy'))
        np.save(tfidf_file, similarity_matrix)

        # Compute TextRank scores
        textrank_scores = compute_textrank(similarity_matrix)

        # Save TextRank scores
        tr_file = os.path.join(TEXTRANK_OUTPUT_DIR, file_name.replace('.json', '_TextRank.txt'))
        with open(tr_file, 'w', encoding='utf-8') as f:
            for score in textrank_scores:
                f.write(f"{score:.6f}\n")

        print(f"Processed {file_name} -> TF-IDF and TextRank saved")
# Out:
# Processed Cloud intelligent track - Risk analysis and privacy data management in the cloud computing.json -> TF-IDF and TextRank saved
# Processed Real-Time Air Quality Monitoring with Edge AI and Machine Learning Algorithm.json -> TF-IDF and TextRank saved
# Processed A Bibliometric View of AI Ethics Development.json -> TF-IDF and TextRank saved
# Processed Software Defined Privacy.json -> TF-IDF and TextRank saved
# Processed Privacy-Diffusion Privacy-Preserving Stable Diffusion Without Homomorphic Encryption.json -> TF-IDF and TextRank saved
# Processed WIP Using Stories from Traditional Culture to Teach Virtue-Based Engineering Ethics.json -> TF-IDF and TextRank saved
# Processed Ethics of Artificial Intelligence in University Education.json -> TF-IDF and TextRank saved
# Processed Methodological Reflections on Designing Surveys to Explore Faculty and Administrator Perceptions of AI Ethics Education.json -> TF-IDF and TextRank saved
# Processed Applying Communication Privacy Management Theory to Youth Privacy Management in AI Contexts.json -> TF-IDF and TextRank saved
# Processed Fuzzy-based Encryption Mechanism for Privacy Preservation and Evaluation of Query Response Time in Cloud.json -> TF-IDF and TextRank saved
# Processed Enhancing Healthcare Data Security and Privacy through AI-Driven Encryption and Privacy-Preserving Techniques.json -> TF-IDF and TextRank saved
# Processed AI and Data Privacy in Business.json -> TF-IDF and TextRank saved
# Processed A Privacy Impact Assessment Tool for Cloud Computing.json -> TF-IDF and TextRank saved
# Processed Ethics Documents in the Field of AI. Concepts- Achievements and Problems.json -> TF-IDF and TextRank saved
# Processed AI Governance A General Perspective.json -> TF-IDF and TextRank saved
# Processed Enhancing Data Privacy in Edge-based Driver AI Monitoring Systems Through Adaptive Differential Privacy.json -> TF-IDF and TextRank saved
# Processed An overview of privacy preserving schemes for industrial Internet of Things.json -> TF-IDF and TextRank saved
# Processed Differential Privacy and k-Anonymity-Based Privacy Preserving Data Publishing Scheme With Minimal Loss of Statistical Information.json -> TF-IDF and TextRank saved
# Processed ETHAI implementation. A Co-Constructive way for Embedding Ethics in Healthcare AI Development.json -> TF-IDF and TextRank saved
# Processed Speech Act Theory and Ethics of Speech Processing as Distinct Stages the ethics of collecting- contextualizing and the releasing of -speech- data.json -> TF-IDF and TextRank saved
# Processed A novel framework to prevent privacy breach in cloud data storage area service.json -> TF-IDF and TextRank saved
# Processed PccP A model for Preserving cloud computing Privacy.json -> TF-IDF and TextRank saved
# Processed Guidelines to Develop AI Ethics Policy in Organizations Perspectives Informed from Two Different Countries- Laws.json -> TF-IDF and TextRank saved
# Processed A Privacy Maturity Model for Cloud Storage Services.json -> TF-IDF and TextRank saved
# Processed Impact of AI Driven Predictive Privacy Mechanisms in UAV Integrated V2X 6G Networks.json -> TF-IDF and TextRank saved
# Processed PRIV-ML Analyzing Privacy Loss in Iterative Machine Learning with Differential Privacy.json -> TF-IDF and TextRank saved
# Processed Narrative-Based AI Ethics Education for Emerging Technologies Leveraging -The Monkey-s Paw- for AI Alignment and Social Justice.json -> TF-IDF and TextRank saved
# Processed CenterYou-- Lightweight Privacy Enforcement for Android Using Hybrid AI and Cloud Decision Support.json -> TF-IDF and TextRank saved
# Processed Imagine a More Ethical AI Using Stories to Develop Teens- Awareness and Understanding of Artificial Intelligence and its Societal Impacts.json -> TF-IDF and TextRank saved
# Processed The Limits of Care A Critical Analysis of AI Companions- Capacity for Good Care.json -> TF-IDF and TextRank saved
# Processed Privacy-Preserved Mobile Sensing through Hybrid Cloud Trust Framework.json -> TF-IDF and TextRank saved
# Processed AI Governance and Ethics in Public Procurement Bridging the Gap Between Theory and Practice.json -> TF-IDF and TextRank saved
# Processed Factors influencing information privacy concern in cloud computing environment.json -> TF-IDF and TextRank saved
# Processed Implementing AI Ethics in the Design of AI-assisted Rescue Robots.json -> TF-IDF and TextRank saved
# Processed Designing Artificial Intelligence with Privacy at the Center.json -> TF-IDF and TextRank saved
# Processed Understanding How Privacy and Data Protection Perceptions Shape Nigerian Journalists- Use of AI Tools A Work in Progress.json -> TF-IDF and TextRank saved
# Processed AI Ethics in Healthcare - A Survey.json -> TF-IDF and TextRank saved
# Processed Privacy Preserving Data Sharing in Cloud Using EAE Technique.json -> TF-IDF and TextRank saved
# Processed Towards a global Code of Ethics for engineers.json -> TF-IDF and TextRank saved
# Processed A Privacy-Leakage-Tolerance Based Noise Enhancing Strategy for Privacy Protection in Cloud Computing.json -> TF-IDF and TextRank saved
# Processed Privacy protected documents on openstack cloud.json -> TF-IDF and TextRank saved
# Processed Exploring Translational Ethical Competency -TEC- in AI Design Conceptual Analysis and Methodological Reflections from a Pilot Study.json -> TF-IDF and TextRank saved
# Processed Mitigating Values Debt in Generative AI Responsible Engineering with Graph RAG.json -> TF-IDF and TextRank saved
# Processed AI Ethics Impact Assessment based on Requirement Engineering.json -> TF-IDF and TextRank saved
# Processed Privacy and Copyright Protection in Generative AI A Lifecycle Perspective.json -> TF-IDF and TextRank saved
# Processed The potential for co-operatives to mitigate AI ethics catastrophes perspectives from media analysis.json -> TF-IDF and TextRank saved
# Processed The Perspective of Dimensional Perpetuity for Artificial Intelligence A Model on Socio-Legal and Political Evolution as a Challenge to Entrepreneurial Ethics.json -> TF-IDF and TextRank saved
# Processed Advancing Ethical AI A Methodological and Empirical Approach to the AI Moral Code.json -> TF-IDF and TextRank saved
# Processed AI Model Training Data Privacy Protection Scheme Based on Local Differential Privacy.json -> TF-IDF and TextRank saved
# Processed Privacy-Preserving Keyword Search Schemes over Encrypted Cloud Data An Extensive Analysis.json -> TF-IDF and TextRank saved
# Processed Ethics and military engineering operations.json -> TF-IDF and TextRank saved
# Processed Advanced Techniques for Protecting Privacy in Artificial Intelligence Powered Medical Systems.json -> TF-IDF and TextRank saved
# Processed Towards a Stakeholder-Oriented Taxonomical Approach for Secure Cloud Computing.json -> TF-IDF and TextRank saved
# Processed Computer Science Ethics Education in Australia - A Work in Progress.json -> TF-IDF and TextRank saved
# Processed Teaching AI Ethics in Technical and Professional Communication A Systematic Review.json -> TF-IDF and TextRank saved
# Processed StopHateForProfit and the ethics of boycotting by corporations.json -> TF-IDF and TextRank saved
# Processed Ethical and Legal Implications of AI on Business and Employment Privacy- Bias- and Accountability.json -> TF-IDF and TextRank saved
# Processed Security and Privacy Issues within the Cloud Computing.json -> TF-IDF and TextRank saved
# Processed Privacy Preserving Data Integration across Autonomous Cloud Services.json -> TF-IDF and TextRank saved
# Processed Bridging Industry- Government- and Academia for Socially Responsible AI The CSEAI Initiative.json -> TF-IDF and TextRank saved
# Processed A privacy-preserving mechanism based on local differential privacy in edge computing.json -> TF-IDF and TextRank saved
# Processed Ethical AI Conundrum Accountability and Liability of AI decision making.json -> TF-IDF and TextRank saved
# Processed Artificial Intelligence Ethics Anthropocentric Approach.json -> TF-IDF and TextRank saved
# Processed A Model for Using Ethical Theory to Specify Epistemic Goals for Explainable AI.json -> TF-IDF and TextRank saved
# Processed Are science- technology- and engineering now the most important subjects for ethics- Our need to respond.json -> TF-IDF and TextRank saved
# Processed Exploring the Privacy Paradox in AI Adoption A Data-Driven Analysis of User Engagement.json -> TF-IDF and TextRank saved
# Processed The IEEE Global Initiative on Ethics of Extended Reality -XR- Report--Extended Reality -XR- Ethics in Medicine.json -> TF-IDF and TextRank saved
# Processed Thou shalt not-A look at the ethics of copying software code.json -> TF-IDF and TextRank saved
# Processed AI Ethics in IoT Involving Society in the Discussion.json -> TF-IDF and TextRank saved
# Processed Perceptions of AI Ethics on Social Media.json -> TF-IDF and TextRank saved
# Processed Ethics- Privacy- and Security Challenges in AI and Blockchain-Driven Digital Health Ecosystems.json -> TF-IDF and TextRank saved
# Processed AI-Generated Privacy-Preserving Protocols for Cross-Cloud Data Sharing and Collaboration.json -> TF-IDF and TextRank saved
# Processed Deep Learning Framework with Explainable AI for Accurate and Interpretable Brain Tumor Segmentation.json -> TF-IDF and TextRank saved
# Processed Security and Privacy Challenges in Multi-Tenant Cloud Architectures A Comprehensive Analysis.json -> TF-IDF and TextRank saved
# Processed Explainable AI and Big Data Analytics for Data Security Risk and Privacy Issues in the Financial Industry.json -> TF-IDF and TextRank saved
# Processed Introducing the concept of ikigai to the ethics of AI and of human enhancements.json -> TF-IDF and TextRank saved
# Processed Ethics of AI as practical ethics.json -> TF-IDF and TextRank saved
# Processed Ethical AI Towards Defining a Collective Evaluation Framework.json -> TF-IDF and TextRank saved
# Processed Introducing graduate and undergraduate students to research and professional ethics at Columbia University.json -> TF-IDF and TextRank saved
# Processed Robust and Secure Federated Learning With Verifiable Differential Privacy.json -> TF-IDF and TextRank saved
# Processed AI Ethics and Data Privacy compliance.json -> TF-IDF and TextRank saved
# Processed On current trends in security and privacy of cloud computing.json -> TF-IDF and TextRank saved
# Processed Preserving privacy in medical images while still enabling AI-driven research A comprehensive review.json -> TF-IDF and TextRank saved
# Processed SDG-Based AI Ethics An Analysis of Recent Computer Vision Research.json -> TF-IDF and TextRank saved
# Processed Privacy Smells Detecting Privacy Problems in Cloud Architectures.json -> TF-IDF and TextRank saved
# Processed Trust Me Over My Privacy Policy- Privacy Discrepancies in Romantic AI Chatbot Apps.json -> TF-IDF and TextRank saved
# Processed Interaction between ethics and technology.json -> TF-IDF and TextRank saved
# Processed Ethics in the Future of AI - A Philosophical Perspective for Collaborative Human and Machine Learning Know-What and Know-How.json -> TF-IDF and TextRank saved
# Processed An Analysis of Security and Privacy Issues in Smart Grid Software Architectures on Clouds.json -> TF-IDF and TextRank saved
# Processed Trading-Off Privacy- Utility- and Explainability in Deep Learning-Based Image Data Analysis.json -> TF-IDF and TextRank saved
# Processed Press Release Ethics in AI Performative Ethics in for-Profit AI Companies.json -> TF-IDF and TextRank saved
# Processed Privacy-Preserving Data Dissemination in Untrusted Cloud.json -> TF-IDF and TextRank saved
# Processed Research on Data Encryption and Privacy Protection Technologies in Cloud Computing Environments.json -> TF-IDF and TextRank saved
# Processed Ethics and Biomedical engineering education The continual defiance.json -> TF-IDF and TextRank saved
# Processed Distributed- Privacy-Aware Location Data Aggregation.json -> TF-IDF and TextRank saved
# Processed The Ethics of AI in Literature Reflections On Representation and Responsibility.json -> TF-IDF and TextRank saved
# Processed Efficient Framework Approach to Extract Privacy Issues in Cloud Computing.json -> TF-IDF and TextRank saved
# Processed Comparison of Privacy-Preserving Models Based on a Third-Party Auditor in Cloud Computing.json -> TF-IDF and TextRank saved
# Processed Advancing AI Ethics in Engineering Curricula in Europe A Case Study Approach.json -> TF-IDF and TextRank saved
# Processed An approach for privacy policies negotiation in mobile health-Cloud environments.json -> TF-IDF and TextRank saved
# Processed The Ethics of AI in Games.json -> TF-IDF and TextRank saved
# Processed Ethics of Artificial Intelligence for Cultural Heritage Opportunities and Challenges.json -> TF-IDF and TextRank saved
# Processed Unpacking Youth Privacy Management in AI Systems A Privacy Calculus Model Analysis.json -> TF-IDF and TextRank saved
# Processed The privacy-aware access control system using attribute-and role-based access control in private cloud.json -> TF-IDF and TextRank saved

# %%
from google.colab import files
import shutil

# Path to your TF-IDF folder
tfidf_folder = '/content/drive/MyDrive/TF-ID_similarity_matrix/'

# Path for the zip file
tfidf_zip = '/content/drive/MyDrive/TF-ID_similarity_matrix.zip'

# Zip the folder
shutil.make_archive(tfidf_zip.replace('.zip',''), 'zip', tfidf_folder)

# Download the zip
files.download(tfidf_zip)

# %%
from google.colab import files
import shutil

# Path to your TextRank folder
textrank_folder = '/content/drive/MyDrive/Textrank_scores/'

# Path for the zip file
textrank_zip = '/content/drive/MyDrive/Textrank_scores.zip'

# Zip the folder
shutil.make_archive(textrank_zip.replace('.zip',''), 'zip', textrank_folder)

# Download the zip
files.download(textrank_zip)
