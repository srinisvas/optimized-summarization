# %%
from google.colab import drive
drive.mount('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %%
import os

repo_path = '/content/optimized-summarization'
if not os.path.exists(repo_path):
    # !git clone https://github.com/srinisvas/optimized-summarization.git
else:
    print("Repo already exists, skipping clone.")

# Check files inside
os.listdir(repo_path)
# Out:
# Repo already exists, skipping clone.
# ['.git', '.idea', 'optimized-summarization', 'README.md']

# %%
import os
  # Adjust your folder
INPUT_DIR = '/content/optimized-summarization/optimized-summarization/Normalized-papers/'
TF_IDF_OUTPUT_DIR = '/content/drive/MyDrive/TF-ID_similarity_matrix/'
TEXTRANK_OUTPUT_DIR = '/content/drive/MyDrive/Textrank_scores/'
BERTSUM_OUTPUT_DIR = '/content/drive/MyDrive/BERTSUM_final_selection/'

os.makedirs(TF_IDF_OUTPUT_DIR, exist_ok=True)
os.makedirs(TEXTRANK_OUTPUT_DIR, exist_ok=True)

# %%
import json
import spacy

nlp = spacy.load("en_core_web_sm")

def extract_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        paper = json.load(f)
    sentences = []
    for sec in paper['sections']:
        doc = nlp(sec['content'])
        sentences.extend([sent for sent in doc.sents])
    return sentences

# %%
def clean_sentences(sentences):
    sentences_cleaned = []
    for sent in sentences:
        words = [word.text for word in sent if not word.is_punct]
        sentences_cleaned.append(" ".join(words))
    return sentences_cleaned

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def compute_tfidf_similarity(sentences_cleaned):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(sentences_cleaned)
    similarity_matrix = cosine_similarity(tfidf_matrix)
    return tfidf_matrix, similarity_matrix

# %%
import networkx as nx

def compute_textrank(similarity_matrix, damping=0.85, max_iter=100):
    nx_graph = nx.from_numpy_array(similarity_matrix)
    scores = nx.pagerank(nx_graph, alpha=damping, max_iter=max_iter)
    # Convert to list sorted by sentence index
    textrank_scores = [scores[i] for i in range(len(scores))]
    return textrank_scores

# %%
def mmr_selection(sentences, textrank_scores, similarity_matrix, K=10, lam=0.7):
    """
    Selects K sentences using Maximal Marginal Relevance (MMR) to balance relevance
    (TextRank) and diversity (similarity to already selected sentences).
    """
    if not sentences or len(sentences) == 0:
        return []

    # Ensure K does not exceed the number of available sentences
    K = min(K, len(sentences))

    selected = []
    candidate_idx = list(range(len(sentences)))

    for _ in range(K):
        mmr_score = []
        for i in candidate_idx:
            if not selected:
                # First iteration: use pure TextRank score
                mmr_score.append((i, textrank_scores[i]))
            else:
                # Subsequent iterations: calculate MMR
                max_sim = max(similarity_matrix[i][j] for j in selected)
                mmr_val = lam * textrank_scores[i] - (1-lam) * max_sim
                mmr_score.append((i, mmr_val))

        # Select the sentence with the highest MMR score
        mmr_score.sort(key=lambda x: x[1], reverse=True)
        best_idx = mmr_score[0][0]

        selected.append(best_idx)
        candidate_idx.remove(best_idx)

    # Return the *original* sentences (as strings) based on the selected indices
    selected_sentences = [str(sentences[i]) for i in selected]
    return selected_sentences

# --- NEW BERTSUM FUNCTION FOR FINAL RERANKING ---

# Constant for the final number of sentences (e.g., summary size)
FINAL_SUMMARY_SENTENCES = 20

# %%
# !pip install bert-extractive-summarizer transformers
# Out:
# Requirement already satisfied: bert-extractive-summarizer in /usr/local/lib/python3.12/dist-packages (0.10.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from bert-extractive-summarizer) (1.6.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from bert-extractive-summarizer) (3.8.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->bert-extractive-summarizer) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->bert-extractive-summarizer) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->bert-extractive-summarizer) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (0.20.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (2.11.10)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy->bert-extractive-summarizer) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->bert-extractive-summarizer) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->bert-extractive-summarizer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->bert-extractive-summarizer) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->bert-extractive-summarizer) (0.4.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->bert-extractive-summarizer) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->bert-extractive-summarizer) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy->bert-extractive-summarizer) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy->bert-extractive-summarizer) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy->bert-extractive-summarizer) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->bert-extractive-summarizer) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->bert-extractive-summarizer) (7.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy->bert-extractive-summarizer) (3.0.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->bert-extractive-summarizer) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->bert-extractive-summarizer) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->bert-extractive-summarizer) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->bert-extractive-summarizer) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->bert-extractive-summarizer) (0.1.2)

# %%
# Process all files
for file_name in os.listdir(INPUT_DIR):
    if file_name.endswith(".json"):
        file_path = os.path.join(INPUT_DIR, file_name)

        # Extract and clean sentences

        sentences = extract_sentences(file_path)
        sentences_cleaned = clean_sentences(sentences)

        # TF-IDF and similarity
        tfidf_matrix, similarity_matrix = compute_tfidf_similarity(sentences_cleaned)

        # Save TF-IDF similarity matrix
        tfidf_file = os.path.join(TF_IDF_OUTPUT_DIR, file_name.replace('.json', '_similarity.npy'))
        np.save(tfidf_file, similarity_matrix)



        # Compute TextRank scores
        textrank_scores = compute_textrank(similarity_matrix)

        # Save TextRank scores
        tr_file = os.path.join(TEXTRANK_OUTPUT_DIR, file_name.replace('.json', '_TextRank.txt'))
        with open(tr_file, 'w', encoding='utf-8') as f:
            for score in textrank_scores:
                f.write(f"{score:.6f}\n")

        # 4. MMR Selection (Sparse Input Activation - Diversity Stage)
        # K_mmr sets the size of the candidate pool (e.g., 30% of total sentences)
        K_mmr = max(FINAL_SUMMARY_SENTENCES, int(len(sentences) * 0.30))

        mmr_candidate_sentences = mmr_selection(
            sentences,
            textrank_scores,
            similarity_matrix,
            K=K_mmr,
            lam=0.7 # Balance: 70% relevance, 30% diversity
        )

        print(f"-> TextRank/TFIDF done. MMR selected {len(mmr_candidate_sentences)} candidates.")

        # 5. BERTSum Final Selection (Semantic Validation Stage)
        # Assuming paper_id is defined within the loop
        paper_id = file_name.replace('.json', '')
        bertsum_file = os.path.join(BERTSUM_OUTPUT_DIR, f'{paper_id}_final_extraction.txt')


        final_extracted_sentences = select_final_sentences_bertsum(
            mmr_candidate_sentences,
            final_num_sentences=FINAL_SUMMARY_SENTENCES
        )

        # 6. Save final output
        with open(bertsum_file, 'w', encoding='utf-8') as f:
            f.write("\n".join(final_extracted_sentences))

        print(f"-> BERTSum complete. Final {len(final_extracted_sentences)} sentences saved to {bertsum_file}")

print("\nPipeline execution finished for all documents.")


print(f"Processed {file_name} -> TF-IDF and TextRank saved")
# Out:
# -> TextRank/TFIDF done. MMR selected 25 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Computer Science Ethics Education in Australia - A Work in Progress_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 72 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Are science- technology- and engineering now the most important subjects for ethics- Our need to respond_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 21 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Efficient Framework Approach to Extract Privacy Issues in Cloud Computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 30 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/The Ethics of AI in Literature Reflections On Representation and Responsibility_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 35 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/On current trends in security and privacy of cloud computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 45 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/A Bibliometric View of AI Ethics Development_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 112 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/The Ethics of AI in Games_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 51 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Advancing AI Ethics in Engineering Curricula in Europe A Case Study Approach_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 101 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/A privacy-preserving mechanism based on local differential privacy in edge computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 33 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI and Data Privacy in Business_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 38 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Mitigating Values Debt in Generative AI Responsible Engineering with Graph RAG_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 47 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/An approach for privacy policies negotiation in mobile health-Cloud environments_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 54 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Understanding How Privacy and Data Protection Perceptions Shape Nigerian Journalists- Use of AI Tools A Work in Progress_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 84 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/A Privacy-Leakage-Tolerance Based Noise Enhancing Strategy for Privacy Protection in Cloud Computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 132 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Robust and Secure Federated Learning With Verifiable Differential Privacy_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 41 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Real-Time Air Quality Monitoring with Edge AI and Machine Learning Algorithm_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 21 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy-Preserved Mobile Sensing through Hybrid Cloud Trust Framework_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 49 candidates.
# -> BERTSum complete. Final 18 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Interaction between ethics and technology_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 49 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/PRIV-ML Analyzing Privacy Loss in Iterative Machine Learning with Differential Privacy_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 20 candidates.
# -> BERTSum complete. Final 17 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/The Perspective of Dimensional Perpetuity for Artificial Intelligence A Model on Socio-Legal and Political Evolution as a Challenge to Entrepreneurial Ethics_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 31 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Preserving privacy in medical images while still enabling AI-driven research A comprehensive review_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 62 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/A Privacy Impact Assessment Tool for Cloud Computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 37 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/CenterYou-- Lightweight Privacy Enforcement for Android Using Hybrid AI and Cloud Decision Support_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 20 candidates.
# -> BERTSum complete. Final 18 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Implementing AI Ethics in the Design of AI-assisted Rescue Robots_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 35 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Comparison of Privacy-Preserving Models Based on a Third-Party Auditor in Cloud Computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 49 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Advancing Ethical AI A Methodological and Empirical Approach to the AI Moral Code_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 36 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Introducing graduate and undergraduate students to research and professional ethics at Columbia University_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 99 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/The potential for co-operatives to mitigate AI ethics catastrophes perspectives from media analysis_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 21 candidates.
# -> BERTSum complete. Final 14 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy-Diffusion Privacy-Preserving Stable Diffusion Without Homomorphic Encryption_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 43 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Enhancing Healthcare Data Security and Privacy through AI-Driven Encryption and Privacy-Preserving Techniques_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 19 candidates.
# -> BERTSum complete. Final 17 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Perceptions of AI Ethics on Social Media_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 79 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/A Model for Using Ethical Theory to Specify Epistemic Goals for Explainable AI_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 29 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethical and Legal Implications of AI on Business and Employment Privacy- Bias- and Accountability_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 88 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Distributed- Privacy-Aware Location Data Aggregation_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 48 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethical AI Towards Defining a Collective Evaluation Framework_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 81 candidates.
# -> BERTSum complete. Final 18 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Advanced Techniques for Protecting Privacy in Artificial Intelligence Powered Medical Systems_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 20 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Narrative-Based AI Ethics Education for Emerging Technologies Leveraging -The Monkey-s Paw- for AI Alignment and Social Justice_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 27 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Designing Artificial Intelligence with Privacy at the Center_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 41 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Cloud intelligent track - Risk analysis and privacy data management in the cloud computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 41 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/PccP A model for Preserving cloud computing Privacy_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 44 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethical AI Conundrum Accountability and Liability of AI decision making_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 38 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Impact of AI Driven Predictive Privacy Mechanisms in UAV Integrated V2X 6G Networks_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 42 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy Preserving Data Sharing in Cloud Using EAE Technique_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 40 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethics Documents in the Field of AI. Concepts- Achievements and Problems_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 34 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Software Defined Privacy_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 27 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/SDG-Based AI Ethics An Analysis of Recent Computer Vision Research_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 15 candidates.
# -> BERTSum complete. Final 13 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/StopHateForProfit and the ethics of boycotting by corporations_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 124 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Differential Privacy and k-Anonymity-Based Privacy Preserving Data Publishing Scheme With Minimal Loss of Statistical Information_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 26 candidates.
# -> BERTSum complete. Final 18 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI Ethics in IoT Involving Society in the Discussion_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 11 candidates.
# -> BERTSum complete. Final 8 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethics of AI as practical ethics_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 20 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Bridging Industry- Government- and Academia for Socially Responsible AI The CSEAI Initiative_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 60 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI Ethics Impact Assessment based on Requirement Engineering_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 39 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Security and Privacy Issues within the Cloud Computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 51 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI Ethics in Healthcare - A Survey_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 33 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/The privacy-aware access control system using attribute-and role-based access control in private cloud_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 37 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI Model Training Data Privacy Protection Scheme Based on Local Differential Privacy_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 20 candidates.
# -> BERTSum complete. Final 18 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Imagine a More Ethical AI Using Stories to Develop Teens- Awareness and Understanding of Artificial Intelligence and its Societal Impacts_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 36 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Exploring the Privacy Paradox in AI Adoption A Data-Driven Analysis of User Engagement_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 55 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/ETHAI implementation. A Co-Constructive way for Embedding Ethics in Healthcare AI Development_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 55 candidates.
# -> BERTSum complete. Final 17 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethics in the Future of AI - A Philosophical Perspective for Collaborative Human and Machine Learning Know-What and Know-How_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 51 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Methodological Reflections on Designing Surveys to Explore Faculty and Administrator Perceptions of AI Ethics Education_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 90 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/An overview of privacy preserving schemes for industrial Internet of Things_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 48 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Fuzzy-based Encryption Mechanism for Privacy Preservation and Evaluation of Query Response Time in Cloud_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 36 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI-Generated Privacy-Preserving Protocols for Cross-Cloud Data Sharing and Collaboration_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 35 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Research on Data Encryption and Privacy Protection Technologies in Cloud Computing Environments_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 20 candidates.
# -> BERTSum complete. Final 17 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy protected documents on openstack cloud_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 46 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Explainable AI and Big Data Analytics for Data Security Risk and Privacy Issues in the Financial Industry_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 33 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy Preserving Data Integration across Autonomous Cloud Services_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 36 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Enhancing Data Privacy in Edge-based Driver AI Monitoring Systems Through Adaptive Differential Privacy_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 22 candidates.
# -> BERTSum complete. Final 18 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/A novel framework to prevent privacy breach in cloud data storage area service_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 32 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/The Limits of Care A Critical Analysis of AI Companions- Capacity for Good Care_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 46 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy and Copyright Protection in Generative AI A Lifecycle Perspective_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 117 candidates.
# -> BERTSum complete. Final 16 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Speech Act Theory and Ethics of Speech Processing as Distinct Stages the ethics of collecting- contextualizing and the releasing of -speech- data_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 27 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethics of Artificial Intelligence in University Education_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 84 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Teaching AI Ethics in Technical and Professional Communication A Systematic Review_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 60 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Introducing the concept of ikigai to the ethics of AI and of human enhancements_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 113 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Trust Me Over My Privacy Policy- Privacy Discrepancies in Romantic AI Chatbot Apps_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 82 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/The IEEE Global Initiative on Ethics of Extended Reality -XR- Report--Extended Reality -XR- Ethics in Medicine_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 51 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI Governance A General Perspective_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 35 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy-Preserving Keyword Search Schemes over Encrypted Cloud Data An Extensive Analysis_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 65 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI Governance and Ethics in Public Procurement Bridging the Gap Between Theory and Practice_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 32 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethics and Biomedical engineering education The continual defiance_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 117 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethics of Artificial Intelligence for Cultural Heritage Opportunities and Challenges_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 24 candidates.
# -> BERTSum complete. Final 14 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/AI Ethics and Data Privacy compliance_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 62 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/An Analysis of Security and Privacy Issues in Smart Grid Software Architectures on Clouds_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 4 candidates.
# -> BERTSum complete. Final 2 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Artificial Intelligence Ethics Anthropocentric Approach_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 94 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy Smells Detecting Privacy Problems in Cloud Architectures_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 33 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Deep Learning Framework with Explainable AI for Accurate and Interpretable Brain Tumor Segmentation_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 45 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Exploring Translational Ethical Competency -TEC- in AI Design Conceptual Analysis and Methodological Reflections from a Pilot Study_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 37 candidates.
# -> BERTSum complete. Final 21 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Factors influencing information privacy concern in cloud computing environment_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 72 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Press Release Ethics in AI Performative Ethics in for-Profit AI Companies_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 75 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Guidelines to Develop AI Ethics Policy in Organizations Perspectives Informed from Two Different Countries- Laws_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 20 candidates.
# -> BERTSum complete. Final 18 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Towards a Stakeholder-Oriented Taxonomical Approach for Secure Cloud Computing_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 40 candidates.
# -> BERTSum complete. Final 19 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/WIP Using Stories from Traditional Culture to Teach Virtue-Based Engineering Ethics_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 68 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Applying Communication Privacy Management Theory to Youth Privacy Management in AI Contexts_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 41 candidates.
# -> BERTSum complete. Final 9 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Towards a global Code of Ethics for engineers_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 27 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Thou shalt not-A look at the ethics of copying software code_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 146 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Trading-Off Privacy- Utility- and Explainability in Deep Learning-Based Image Data Analysis_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 34 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethics and military engineering operations_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 20 candidates.
# -> BERTSum complete. Final 16 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/A Privacy Maturity Model for Cloud Storage Services_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 58 candidates.
# -> BERTSum complete. Final 18 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Ethics- Privacy- and Security Challenges in AI and Blockchain-Driven Digital Health Ecosystems_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 45 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Security and Privacy Challenges in Multi-Tenant Cloud Architectures A Comprehensive Analysis_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 42 candidates.
# -> BERTSum complete. Final 22 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Privacy-Preserving Data Dissemination in Untrusted Cloud_final_extraction.txt
# -> TextRank/TFIDF done. MMR selected 152 candidates.
# -> BERTSum complete. Final 20 sentences saved to /content/drive/MyDrive/BERTSUM_final_selection/Unpacking Youth Privacy Management in AI Systems A Privacy Calculus Model Analysis_final_extraction.txt
#
# Pipeline execution finished for all documents.
# Processed Unpacking Youth Privacy Management in AI Systems A Privacy Calculus Model Analysis.json -> TF-IDF and TextRank saved

# %%
# --- Define the paths based on your pipeline file ---
# Path to your BERTSum output folder (copied from pipeline_with_bertsum.py)
BERTSUM_OUTPUT_DIR = '/content/drive/MyDrive/BERTSUM_final_selection/'
output_folder = BERTSUM_OUTPUT_DIR

# Path for the zip file
output_zip = '/content/drive/MyDrive/BERTSUM_final_selection.zip'

# Check if the folder exists before attempting to zip
if not os.path.exists(output_folder):
    print(f"Error: Output folder not found at {output_folder}")
else:
    # Zip the folder. shutil.make_archive takes (base_name, format, root_dir)
    # The base_name is the full path/filename without extension.
    print(f"Zipping folder: {output_folder}...")
    shutil.make_archive(output_zip.replace('.zip',''), 'zip', output_folder)
    print(f"Zip created successfully at {output_zip}")

    # Download the zip
    files.download(output_zip)
    print("Download initiated.")
# Out:
# Zipping folder: /content/drive/MyDrive/BERTSUM_final_selection/...
# Zip created successfully at /content/drive/MyDrive/BERTSUM_final_selection.zip
# Download initiated.
